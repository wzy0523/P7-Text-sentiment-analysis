# %%
import numpy as np
import pandas as pd 
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from sklearn.utils import resample
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
import re
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import KFold

# %%
#1.read in data
filenames=["covid_preprocess_full.csv","email_preprocess_full.csv","imdb_preprocess_full.csv",
          "news_preprocess_full.csv","review_preprocess_full.csv","twitter_preprocess.csv",
          "finance_preprocess.csv","paper_preprocess.csv","reddit_preprocess.csv"]
data = pd.read_csv('dataset/'+filenames[1])
#use two column
data = data[['sw_exclude','sentiment']]
#use 1000 data
data=data[:1000]
data
len(data)
# Out:
# 105

# %%
#2.set data
#hyperparameters(max_fatures,embed_dim,lstm_out,batch_size,droupout_x)
#use softmax beacuse use categorical crossentropy
#X is text,Y is sentiment
max_fatures = 2000
tokenizer = Tokenizer(num_words=max_fatures, split=' ')
data['sw_exclude']=data['sw_exclude'].fillna("")
tokenizer.fit_on_texts(data['sw_exclude'].values)
X = tokenizer.texts_to_sequences(data['sw_exclude'].values)
X = pad_sequences(X)
Y = to_categorical(data['sentiment'].values+1)

#initial model and set hyperparameters
def get_model():
    #use softmax beacuse use categorical crossentropy
    embed_dim = 128
    lstm_out = 100
    model = Sequential()
    model.add(Embedding(max_fatures, embed_dim,input_length = X.shape[1]))
    model.add(SpatialDropout1D(0.4))
    model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
    # has to reflect the number of classes that are being predicted. Here 3 classes are being used 
    model.add(Dense(3,activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
    print(model.summary())
    return model

# %%
#use cv
kf = KFold(n_splits=5)

accList=list()
for train_index, test_index in kf.split(X):
    X_train=X[train_index]
    Y_train=Y[train_index]
    X_test=X[test_index]
    Y_test=Y[test_index]
    
    batch_size = 128
    model=get_model()
    model.fit(X_train, Y_train, epochs = 10, batch_size=batch_size, verbose = 1)
    
    Y_pred=np.argmax(model.predict(X_test), axis=-1)
    df_test = pd.DataFrame({'true': Y_test.tolist(), 'pred':Y_pred})
    df_test['true'] = df_test['true'].apply(lambda x: np.argmax(x))
    print("test accuracy:")
    acc=sum(df_test.pred==df_test.true)/len(X_test)
    print(acc)
    #confusion matrix
    #print("confusion matrix",confusion_matrix(df_test.true, df_test.pred))
    #print(classification_report(df_test.true, df_test.pred))
    accList.append(acc)

print("accuracy list:{}".format(accList))
print("mean accuracy:{} ".format(np.mean(accList)))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 107, 128)          256000
#
#  spatial_dropout1d_2 (Spatia  (None, 107, 128)         0
#  lDropout1D)
#
#  lstm_2 (LSTM)               (None, 100)               91600
#
#  dense_2 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 1.1006 - accuracy: 0.2500
# Epoch 2/10
# 1/1 [==============================] - 0s 412ms/step - loss: 1.0916 - accuracy: 0.5714
# Epoch 3/10
# 1/1 [==============================] - 0s 403ms/step - loss: 1.0834 - accuracy: 0.6190
# Epoch 4/10
# 1/1 [==============================] - 0s 429ms/step - loss: 1.0714 - accuracy: 0.6071
# Epoch 5/10
# 1/1 [==============================] - 0s 399ms/step - loss: 1.0592 - accuracy: 0.5952
# Epoch 6/10
# 1/1 [==============================] - 0s 406ms/step - loss: 1.0490 - accuracy: 0.5476
# Epoch 7/10
# 1/1 [==============================] - 0s 407ms/step - loss: 1.0326 - accuracy: 0.5595
# Epoch 8/10
# 1/1 [==============================] - 0s 415ms/step - loss: 1.0147 - accuracy: 0.5595
# Epoch 9/10
# 1/1 [==============================] - 0s 408ms/step - loss: 0.9915 - accuracy: 0.5595
# Epoch 10/10
# 1/1 [==============================] - 0s 416ms/step - loss: 0.9696 - accuracy: 0.5595
# 1/1 [==============================] - 0s 250ms/step
# test accuracy:
# 0.5238095238095238
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 107, 128)          256000
#
#  spatial_dropout1d_3 (Spatia  (None, 107, 128)         0
#  lDropout1D)
#
#  lstm_3 (LSTM)               (None, 100)               91600
#
#  dense_3 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 1.0976 - accuracy: 0.3810
# Epoch 2/10
# 1/1 [==============================] - 0s 371ms/step - loss: 1.0847 - accuracy: 0.6071
# Epoch 3/10
# 1/1 [==============================] - 0s 417ms/step - loss: 1.0698 - accuracy: 0.6190
# Epoch 4/10
# 1/1 [==============================] - 0s 391ms/step - loss: 1.0519 - accuracy: 0.6071
# Epoch 5/10
# 1/1 [==============================] - 0s 365ms/step - loss: 1.0386 - accuracy: 0.6071
# Epoch 6/10
# 1/1 [==============================] - 0s 385ms/step - loss: 1.0118 - accuracy: 0.6071
# Epoch 7/10
# 1/1 [==============================] - 0s 384ms/step - loss: 0.9911 - accuracy: 0.6071
# Epoch 8/10
# 1/1 [==============================] - 0s 365ms/step - loss: 0.9453 - accuracy: 0.6071
# Epoch 9/10
# 1/1 [==============================] - 0s 398ms/step - loss: 0.9230 - accuracy: 0.6071
# Epoch 10/10
# 1/1 [==============================] - 0s 383ms/step - loss: 0.9443 - accuracy: 0.6071
# 1/1 [==============================] - 0s 221ms/step
# test accuracy:
# 0.3333333333333333
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 107, 128)          256000
#
#  spatial_dropout1d_4 (Spatia  (None, 107, 128)         0
#  lDropout1D)
#
#  lstm_4 (LSTM)               (None, 100)               91600
#
#  dense_4 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 1.1037 - accuracy: 0.2500
# Epoch 2/10
# 1/1 [==============================] - 0s 462ms/step - loss: 1.0919 - accuracy: 0.4643
# Epoch 3/10
# 1/1 [==============================] - 0s 460ms/step - loss: 1.0803 - accuracy: 0.6071
# Epoch 4/10
# 1/1 [==============================] - 0s 476ms/step - loss: 1.0699 - accuracy: 0.5595
# Epoch 5/10
# 1/1 [==============================] - 1s 506ms/step - loss: 1.0565 - accuracy: 0.5476
# Epoch 6/10
# 1/1 [==============================] - 0s 478ms/step - loss: 1.0411 - accuracy: 0.5476
# Epoch 7/10
# 1/1 [==============================] - 0s 454ms/step - loss: 1.0185 - accuracy: 0.5476
# Epoch 8/10
# 1/1 [==============================] - 0s 486ms/step - loss: 1.0003 - accuracy: 0.5476
# Epoch 9/10
# 1/1 [==============================] - 0s 475ms/step - loss: 0.9650 - accuracy: 0.5476
# Epoch 10/10
# 1/1 [==============================] - 0s 468ms/step - loss: 0.9682 - accuracy: 0.5476
# 1/1 [==============================] - 0s 231ms/step
# test accuracy:
# 0.5714285714285714
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 107, 128)          256000
#
#  spatial_dropout1d_5 (Spatia  (None, 107, 128)         0
#  lDropout1D)
#
#  lstm_5 (LSTM)               (None, 100)               91600
#
#  dense_5 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 1.1000 - accuracy: 0.3214
# Epoch 2/10
# 1/1 [==============================] - 0s 463ms/step - loss: 1.0913 - accuracy: 0.5357
# Epoch 3/10
# 1/1 [==============================] - 0s 441ms/step - loss: 1.0810 - accuracy: 0.5952
# Epoch 4/10
# 1/1 [==============================] - 0s 479ms/step - loss: 1.0731 - accuracy: 0.5714
# Epoch 5/10
# 1/1 [==============================] - 0s 474ms/step - loss: 1.0597 - accuracy: 0.5833
# Epoch 6/10
# 1/1 [==============================] - 0s 471ms/step - loss: 1.0454 - accuracy: 0.5238
# Epoch 7/10
# 1/1 [==============================] - 1s 504ms/step - loss: 1.0272 - accuracy: 0.5238
# Epoch 8/10
# 1/1 [==============================] - 0s 494ms/step - loss: 1.0085 - accuracy: 0.5238
# Epoch 9/10
# 1/1 [==============================] - 0s 439ms/step - loss: 0.9928 - accuracy: 0.5238
# Epoch 10/10
# 1/1 [==============================] - 0s 496ms/step - loss: 0.9892 - accuracy: 0.5238
# 1/1 [==============================] - 0s 242ms/step
# test accuracy:
# 0.6666666666666666
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 107, 128)          256000
#
#  spatial_dropout1d_6 (Spatia  (None, 107, 128)         0
#  lDropout1D)
#
#  lstm_6 (LSTM)               (None, 100)               91600
#
#  dense_6 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 1.0977 - accuracy: 0.4048
# Epoch 2/10
# 1/1 [==============================] - 1s 611ms/step - loss: 1.0900 - accuracy: 0.5357
# Epoch 3/10
# 1/1 [==============================] - 1s 579ms/step - loss: 1.0809 - accuracy: 0.5714
# Epoch 4/10
# 1/1 [==============================] - 1s 617ms/step - loss: 1.0697 - accuracy: 0.5952
# Epoch 5/10
# 1/1 [==============================] - 1s 691ms/step - loss: 1.0578 - accuracy: 0.5595
# Epoch 6/10
# 1/1 [==============================] - 1s 607ms/step - loss: 1.0435 - accuracy: 0.5238
# Epoch 7/10
# 1/1 [==============================] - 1s 615ms/step - loss: 1.0297 - accuracy: 0.5238
# Epoch 8/10
# 1/1 [==============================] - 1s 573ms/step - loss: 1.0088 - accuracy: 0.5238
# Epoch 9/10
# 1/1 [==============================] - 1s 675ms/step - loss: 0.9978 - accuracy: 0.5238
# Epoch 10/10
# 1/1 [==============================] - 1s 591ms/step - loss: 0.9675 - accuracy: 0.5238
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000218B2D04430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 251ms/step
# test accuracy:
# 0.6666666666666666
# accuracy list:[0.5238095238095238, 0.3333333333333333, 0.5714285714285714, 0.6666666666666666, 0.6666666666666666]
# mean accuracy:0.5523809523809524
