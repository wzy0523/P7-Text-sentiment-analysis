# %%
import numpy as np
import pandas as pd 
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from sklearn.utils import resample
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
import re
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import KFold

# %%
#1.read in data
filenames=["covid_preprocess_full.csv","email_preprocess_full.csv","imdb_preprocess_full.csv",
          "news_preprocess_full.csv","review_preprocess_full.csv","twitter_preprocess.csv"]
data = pd.read_csv('dataset/'+filenames[0])
#use two column
data = data[['sw_exclude','sentiment']]
#use 1000 data
data=data[:1000]
data.head()
# Out:
#                                           sw_exclude  sentiment
# 0  rajasthan wednesday report 74 new coronavirus ...         -1
# 1  total number coronavirus case delhi surge 3 43...         -1
# 2  condole demise actor rishi kapoor pm narendra ...          1
# 3  congress leader rahul gandhi condole rishi kap...         -1
# 4  sign respect healthcare professional fight cov...          1

# %%
#2.set data
#hyperparameters(max_fatures,embed_dim,lstm_out,batch_size,droupout_x)
#use softmax beacuse use categorical crossentropy
#X is text,Y is sentiment
max_fatures = 2000
tokenizer = Tokenizer(num_words=max_fatures, split=' ')
data['sw_exclude']=data['sw_exclude'].fillna("")
tokenizer.fit_on_texts(data['sw_exclude'].values)
X = tokenizer.texts_to_sequences(data['sw_exclude'].values)
X = pad_sequences(X)
Y = to_categorical(data['sentiment'].values+1)

#initial model and set hyperparameters
def get_model():
    #use softmax beacuse use categorical crossentropy
    embed_dim = 128
    lstm_out = 100
    model = Sequential()
    model.add(Embedding(max_fatures, embed_dim,input_length = X.shape[1]))
    model.add(SpatialDropout1D(0.4))
    model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
    # has to reflect the number of classes that are being predicted. Here 3 classes are being used 
    model.add(Dense(3,activation='softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
    print(model.summary())
    return model

# %%
#use cv
kf = KFold(n_splits=5)

accList=list()
for train_index, test_index in kf.split(X):
    X_train=X[train_index]
    Y_train=Y[train_index]
    X_test=X[test_index]
    Y_test=Y[test_index]
    
    batch_size = 128
    model=get_model()
    model.fit(X_train, Y_train, epochs = 10, batch_size=batch_size, verbose = 1)
    
    Y_pred=np.argmax(model.predict(X_test), axis=-1)
    df_test = pd.DataFrame({'true': Y_test.tolist(), 'pred':Y_pred})
    df_test['true'] = df_test['true'].apply(lambda x: np.argmax(x))
    print("test accuracy:")
    acc=sum(df_test.pred==df_test.true)/len(X_test)
    print(acc)
    #confusion matrix
    #print("confusion matrix",confusion_matrix(df_test.true, df_test.pred))
    #print(classification_report(df_test.true, df_test.pred))
    accList.append(acc)

print("accuracy list:{}".format(accList))
print("mean accuracy:{} ".format(np.mean(accList)))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 55, 128)           256000
#
#  spatial_dropout1d (SpatialD  (None, 55, 128)          0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 100)               91600
#
#  dense (Dense)               (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 7/7 [==============================] - 3s 127ms/step - loss: 1.0706 - accuracy: 0.5400
# Epoch 2/10
# 7/7 [==============================] - 1s 127ms/step - loss: 0.8321 - accuracy: 0.6250
# Epoch 3/10
# 7/7 [==============================] - 1s 119ms/step - loss: 0.6767 - accuracy: 0.5975
# Epoch 4/10
# 7/7 [==============================] - 1s 117ms/step - loss: 0.6500 - accuracy: 0.6250
# Epoch 5/10
# 7/7 [==============================] - 1s 118ms/step - loss: 0.6445 - accuracy: 0.6250
# Epoch 6/10
# 7/7 [==============================] - 1s 119ms/step - loss: 0.6213 - accuracy: 0.6275
# Epoch 7/10
# 7/7 [==============================] - 1s 121ms/step - loss: 0.5969 - accuracy: 0.6338
# Epoch 8/10
# 7/7 [==============================] - 1s 118ms/step - loss: 0.5543 - accuracy: 0.8238
# Epoch 9/10
# 7/7 [==============================] - 1s 116ms/step - loss: 0.4488 - accuracy: 0.8200
# Epoch 10/10
# 7/7 [==============================] - 1s 121ms/step - loss: 0.3365 - accuracy: 0.8737
# 7/7 [==============================] - 0s 7ms/step
# test accuracy:
# 0.715
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 55, 128)           256000
#
#  spatial_dropout1d_1 (Spatia  (None, 55, 128)          0
#  lDropout1D)
#
#  lstm_1 (LSTM)               (None, 100)               91600
#
#  dense_1 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 7/7 [==============================] - 3s 127ms/step - loss: 1.0723 - accuracy: 0.5375
# Epoch 2/10
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8634 - accuracy: 0.6225
# Epoch 3/10
# 7/7 [==============================] - 1s 134ms/step - loss: 0.6803 - accuracy: 0.6338
# Epoch 4/10
# 7/7 [==============================] - 1s 138ms/step - loss: 0.6619 - accuracy: 0.6237
# Epoch 5/10
# 7/7 [==============================] - 1s 128ms/step - loss: 0.6353 - accuracy: 0.6425
# Epoch 6/10
# 7/7 [==============================] - 1s 135ms/step - loss: 0.5967 - accuracy: 0.6375
# Epoch 7/10
# 7/7 [==============================] - 1s 135ms/step - loss: 0.5303 - accuracy: 0.7850
# Epoch 8/10
# 7/7 [==============================] - 1s 137ms/step - loss: 0.4164 - accuracy: 0.8050
# Epoch 9/10
# 7/7 [==============================] - 1s 136ms/step - loss: 0.2959 - accuracy: 0.8850
# Epoch 10/10
# 7/7 [==============================] - 1s 135ms/step - loss: 0.1949 - accuracy: 0.9337
# 7/7 [==============================] - 0s 8ms/step
# test accuracy:
# 0.695
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 55, 128)           256000
#
#  spatial_dropout1d_2 (Spatia  (None, 55, 128)          0
#  lDropout1D)
#
#  lstm_2 (LSTM)               (None, 100)               91600
#
#  dense_2 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 7/7 [==============================] - 3s 132ms/step - loss: 1.0714 - accuracy: 0.5688
# Epoch 2/10
# 7/7 [==============================] - 1s 125ms/step - loss: 0.8560 - accuracy: 0.6237
# Epoch 3/10
# 7/7 [==============================] - 1s 126ms/step - loss: 0.6804 - accuracy: 0.5325
# Epoch 4/10
# 7/7 [==============================] - 1s 129ms/step - loss: 0.6689 - accuracy: 0.6300
# Epoch 5/10
# 7/7 [==============================] - 1s 127ms/step - loss: 0.6284 - accuracy: 0.6488
# Epoch 6/10
# 7/7 [==============================] - 1s 127ms/step - loss: 0.6112 - accuracy: 0.7088
# Epoch 7/10
# 7/7 [==============================] - 1s 128ms/step - loss: 0.5712 - accuracy: 0.6413
# Epoch 8/10
# 7/7 [==============================] - 1s 134ms/step - loss: 0.4961 - accuracy: 0.8425
# Epoch 9/10
# 7/7 [==============================] - 1s 131ms/step - loss: 0.3988 - accuracy: 0.8250
# Epoch 10/10
# 7/7 [==============================] - 1s 134ms/step - loss: 0.2950 - accuracy: 0.8788
# 7/7 [==============================] - 0s 8ms/step
# test accuracy:
# 0.76
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 55, 128)           256000
#
#  spatial_dropout1d_3 (Spatia  (None, 55, 128)          0
#  lDropout1D)
#
#  lstm_3 (LSTM)               (None, 100)               91600
#
#  dense_3 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 7/7 [==============================] - 3s 130ms/step - loss: 1.0690 - accuracy: 0.5688
# Epoch 2/10
# 7/7 [==============================] - 1s 125ms/step - loss: 0.8519 - accuracy: 0.6250
# Epoch 3/10
# 7/7 [==============================] - 1s 126ms/step - loss: 0.6822 - accuracy: 0.6388
# Epoch 4/10
# 7/7 [==============================] - 1s 129ms/step - loss: 0.6334 - accuracy: 0.6538
# Epoch 5/10
# 7/7 [==============================] - 1s 133ms/step - loss: 0.6121 - accuracy: 0.6388
# Epoch 6/10
# 7/7 [==============================] - 1s 131ms/step - loss: 0.5649 - accuracy: 0.7500
# Epoch 7/10
# 7/7 [==============================] - 1s 129ms/step - loss: 0.4732 - accuracy: 0.7850
# Epoch 8/10
# 7/7 [==============================] - 1s 124ms/step - loss: 0.3264 - accuracy: 0.8863
# Epoch 9/10
# 7/7 [==============================] - 1s 129ms/step - loss: 0.3608 - accuracy: 0.8263
# Epoch 10/10
# 7/7 [==============================] - 1s 130ms/step - loss: 0.2526 - accuracy: 0.9075
# 7/7 [==============================] - 0s 10ms/step
# test accuracy:
# 0.685
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 55, 128)           256000
#
#  spatial_dropout1d_4 (Spatia  (None, 55, 128)          0
#  lDropout1D)
#
#  lstm_4 (LSTM)               (None, 100)               91600
#
#  dense_4 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 347,903
# Trainable params: 347,903
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 7/7 [==============================] - 3s 144ms/step - loss: 1.0672 - accuracy: 0.5550
# Epoch 2/10
# 7/7 [==============================] - 1s 145ms/step - loss: 0.8057 - accuracy: 0.6338
# Epoch 3/10
# 7/7 [==============================] - 1s 138ms/step - loss: 0.6785 - accuracy: 0.6000
# Epoch 4/10
# 7/7 [==============================] - 1s 145ms/step - loss: 0.6473 - accuracy: 0.6338
# Epoch 5/10
# 7/7 [==============================] - 1s 146ms/step - loss: 0.6309 - accuracy: 0.6338
# Epoch 6/10
# 7/7 [==============================] - 1s 150ms/step - loss: 0.6038 - accuracy: 0.6400
# Epoch 7/10
# 7/7 [==============================] - 1s 145ms/step - loss: 0.5437 - accuracy: 0.6862
# Epoch 8/10
# 7/7 [==============================] - 1s 143ms/step - loss: 0.4242 - accuracy: 0.8537
# Epoch 9/10
# 7/7 [==============================] - 1s 145ms/step - loss: 0.3659 - accuracy: 0.8363
# Epoch 10/10
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2964 - accuracy: 0.8950
# 7/7 [==============================] - 0s 10ms/step
# test accuracy:
# 0.675
# accuracy list:[0.715, 0.695, 0.76, 0.685, 0.675]
# mean accuracy:0.7060000000000001
